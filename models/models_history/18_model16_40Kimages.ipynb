# %%
import os
import math
import random
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from skimage.io import imshow
#from sklearn.model_selection import train_test_split

#import tensorflow as tf

import keras

from keras.preprocessing.image import img_to_array, load_img
from keras.layers import Conv2D
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K

np.random.seed(1337)
# Out:
# Using TensorFlow backend.

# %%
#making sure GPU is in use 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1511368966484648945
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11285289370
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1509638033151965728
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Set some parameters
in_height = 64
in_width = 64
out_height = 256
out_width = 256
color_dim = 3
path_in =  '/home/Matthew/image-super-resolution/data/imagenet/40k/res64noisy/'
path_out = '/home/Matthew/image-super-resolution/data/imagenet/40k/res256/'

# %%
#todo: add random shuffle . seed = 0

def load_images(path_in, path_out, test_size, valid_size):
    images = next(os.walk(path_in))[2] #oswalk is a generator 
    num_images = len(images)
  
    testSize  = int(test_size * num_images)
    validSize = int(valid_size * num_images)
    trainSize = int(math.ceil((1-(test_size+valid_size)) * num_images))
    
    X_train = np.zeros((trainSize,in_height,in_width,color_dim), dtype=np.float32)
    X_test = np.zeros((testSize,in_height,in_width,color_dim), dtype=np.float32)
    X_valid = np.zeros((validSize,in_height,in_width,color_dim), dtype=np.float32)

    y_train = np.zeros((trainSize,out_height,out_width,color_dim), dtype=np.float32)
    y_test  = np.zeros((testSize,out_height,out_width,color_dim), dtype=np.float32)
    y_valid  = np.zeros((validSize,out_height,out_width,color_dim), dtype=np.float32)
    
    trainIdx = 0
    testIdx = 0
    validIdx = 0
    for idx, image in enumerate(images):
        image_in_path = os.path.join(path_in,image)
        image_out_path = os.path.join(path_out,image)

        image_in_raw =  load_img(image_in_path, grayscale=False)
        image_out_raw = load_img(image_out_path, grayscale=False)

        #converts image to keras preprocessing image, then divide by 255 to un-invert the images
        image_in = (img_to_array(image_in_raw)).squeeze() / 255 
        image_out = (img_to_array(image_out_raw)).squeeze() / 255          
 
        try:
            if (idx % 1000 == 0):
                print("Stage " + str(idx))
        
            if (idx < testSize):
                #print("testIdx " + str(testIdx))
                X_test[testIdx] = image_in
                y_test[testIdx] = image_out
                testIdx+=1
                
            elif (idx < testSize + validSize):
                #print("validIdx " + str(validIdx))
                X_valid[validIdx] = image_in
                y_valid[validIdx] = image_out
                validIdx+=1
                
            else:
                #print("trainIdx " + str(trainIdx))
                X_train[trainIdx] = image_in
                y_train[trainIdx] = image_out
                trainIdx+=1
                
        except Exception as e: 
            print("\nERROR!!!!")
            print(image_in.shape)
            print(trainIdx)
            
            print(image_out.shape)
            print(testIdx)
            
            print("id "+str(idx))
            print(image_in_path)
            print(e)
           
            print("\n")
            
    return X_train,X_valid,X_test,y_train,y_valid,y_test

# %%
X_train,X_valid,X_test,y_train,y_valid,y_test = load_images(path_in, path_out, .2, .2)
# Out:
# Stage 0
# Stage 1000
# Stage 2000
# Stage 3000
# Stage 4000
# Stage 5000
# Stage 6000
# Stage 7000
# Stage 8000
# Stage 9000
# Stage 10000
# Stage 11000
# Stage 12000
# Stage 13000
# Stage 14000
# Stage 15000
# Stage 16000
# Stage 17000
# Stage 18000
# Stage 19000
# Stage 20000
# Stage 21000
# Stage 22000
# Stage 23000
# Stage 24000
# Stage 25000
# Stage 26000
# Stage 27000
# Stage 28000
# Stage 29000
# Stage 30000
# Stage 31000
# Stage 32000
# Stage 33000
# Stage 34000
# Stage 35000
# Stage 36000
# Stage 37000
# Stage 38000
# Stage 39000
# Stage 40000

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.core import Activation
from keras import backend as K
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from keras.optimizers import RMSprop

# %%
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers import  BatchNormalization, Activation, Dropout, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
#padding output size: see http://cs231n.github.io/convolutional-networks/
# output = (W−F+2P)/S+1   w- input size, f-kernel size, p-padding size

# %%
#model = Sequential()
#inputShape = (in_height, in_width, color_dim)
#model.add(UpSampling2D((4,4),input_shape=inputShape))
#model.add(Conv2D(32, (9, 9), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 32
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(color_dim, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 3
#model.add(Activation("sigmoid"))

# %%
# https://www.depends-on-the-definition.com/unet-keras-segmenting-images/

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(4, 4), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    
    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
'''def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model'''
# Out:
# "def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):\n    # contracting path\n    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    \n    # expansive path\n    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)\n    u6 = Dropout(dropout)(u6)\n    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)\n\n    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)\n    u7 = Dropout(dropout)(u7)\n    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)\n\n    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)\n    u8 = Dropout(dropout)(u8)\n    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)\n\n    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)\n    u9 = Dropout(dropout)(u9)\n    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)\n    model = Model(inputs=[input_img], outputs=[outputs])\n    return model"

# %%
input_img = Input((in_height, in_width, color_dim), name='img')
model = create_network(input_img, n_filters=8, dropout=0.05, batchnorm=True)

# %%
model.compile(loss='mean_squared_error', optimizer = RMSprop(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 256, 64)      1792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# activation_2 (Activation)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 256, 256, 32)      18464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# activation_3 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# activation_4 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 256, 256, 16)      4624
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256, 256, 16)      64
# _________________________________________________________________
# activation_5 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256, 256, 16)      64
# _________________________________________________________________
# activation_6 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 256, 256, 8)       1160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_7 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_8 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 256, 256, 3)       27
# =================================================================
# Total params: 125,187
# Trainable params: 124,707
# Non-trainable params: 480
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model_16.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
batch_size = 32
epochs = 100
trainHistory = model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_valid, y_valid),callbacks=callbacks)
# Out:
# Train on 24423 samples, validate on 8141 samples
# Epoch 1/100
# 24423/24423 [==============================] - 1315s 54ms/step - loss: 0.0166 - acc: 0.6137 - val_loss: 0.0163 - val_acc: 0.5995
#
# Epoch 00001: val_loss improved from inf to 0.01631, saving model to model_16.h5
# Epoch 2/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0096 - acc: 0.6543 - val_loss: 0.0212 - val_acc: 0.6830
#
# Epoch 00002: val_loss did not improve from 0.01631
# Epoch 3/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0089 - acc: 0.6706 - val_loss: 0.0099 - val_acc: 0.6819
#
# Epoch 00003: val_loss improved from 0.01631 to 0.00990, saving model to model_16.h5
# Epoch 4/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0086 - acc: 0.6783 - val_loss: 0.0096 - val_acc: 0.6727
#
# Epoch 00004: val_loss improved from 0.00990 to 0.00964, saving model to model_16.h5
# Epoch 5/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0083 - acc: 0.6842 - val_loss: 0.0092 - val_acc: 0.7050
#
# Epoch 00005: val_loss improved from 0.00964 to 0.00918, saving model to model_16.h5
# Epoch 6/100
# 24423/24423 [==============================] - 1299s 53ms/step - loss: 0.0081 - acc: 0.6916 - val_loss: 0.0087 - val_acc: 0.6974
#
# Epoch 00006: val_loss improved from 0.00918 to 0.00873, saving model to model_16.h5
# Epoch 7/100
# 24423/24423 [==============================] - 1298s 53ms/step - loss: 0.0078 - acc: 0.6982 - val_loss: 0.0074 - val_acc: 0.6852
#
# Epoch 00007: val_loss improved from 0.00873 to 0.00736, saving model to model_16.h5
# Epoch 8/100
# 24423/24423 [==============================] - 1300s 53ms/step - loss: 0.0077 - acc: 0.7022 - val_loss: 0.0081 - val_acc: 0.7115
#
# Epoch 00008: val_loss did not improve from 0.00736
# Epoch 9/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0076 - acc: 0.7048 - val_loss: 0.0088 - val_acc: 0.6786
#
# Epoch 00009: val_loss did not improve from 0.00736
# Epoch 10/100
# 24423/24423 [==============================] - 1301s 53ms/step - loss: 0.0075 - acc: 0.7085 - val_loss: 0.0086 - val_acc: 0.7171
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00010: val_loss did not improve from 0.00736
# Epoch 11/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0071 - acc: 0.7148 - val_loss: 0.0068 - val_acc: 0.7204
#
# Epoch 00011: val_loss improved from 0.00736 to 0.00678, saving model to model_16.h5
# Epoch 12/100
# 24423/24423 [==============================] - 1301s 53ms/step - loss: 0.0071 - acc: 0.7168 - val_loss: 0.0068 - val_acc: 0.7294
#
# Epoch 00012: val_loss did not improve from 0.00678
# Epoch 13/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0071 - acc: 0.7180 - val_loss: 0.0068 - val_acc: 0.7348
#
# Epoch 00013: val_loss improved from 0.00678 to 0.00676, saving model to model_16.h5
# Epoch 14/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0071 - acc: 0.7192 - val_loss: 0.0068 - val_acc: 0.7364
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00014: val_loss improved from 0.00676 to 0.00675, saving model to model_16.h5
# Epoch 15/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0071 - acc: 0.7208 - val_loss: 0.0067 - val_acc: 0.7353
#
# Epoch 00015: val_loss improved from 0.00675 to 0.00672, saving model to model_16.h5
# Epoch 16/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0071 - acc: 0.7202 - val_loss: 0.0067 - val_acc: 0.7393
#
# Epoch 00016: val_loss did not improve from 0.00672
# Epoch 17/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7201 - val_loss: 0.0067 - val_acc: 0.7414
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00017: val_loss did not improve from 0.00672
# Epoch 18/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7211 - val_loss: 0.0067 - val_acc: 0.7374
#
# Epoch 00018: val_loss did not improve from 0.00672
# Epoch 19/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0071 - acc: 0.7206 - val_loss: 0.0067 - val_acc: 0.7386
#
# Epoch 00019: val_loss improved from 0.00672 to 0.00672, saving model to model_16.h5
# Epoch 20/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7208 - val_loss: 0.0067 - val_acc: 0.7396
#
# Epoch 00020: val_loss improved from 0.00672 to 0.00671, saving model to model_16.h5
# Epoch 21/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0070 - acc: 0.7209 - val_loss: 0.0067 - val_acc: 0.7374
#
# Epoch 00021: val_loss did not improve from 0.00671
# Epoch 22/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7217 - val_loss: 0.0067 - val_acc: 0.7362
#
# Epoch 00022: val_loss improved from 0.00671 to 0.00671, saving model to model_16.h5
# Epoch 23/100
# 24423/24423 [==============================] - 1300s 53ms/step - loss: 0.0070 - acc: 0.7208 - val_loss: 0.0067 - val_acc: 0.7393
#
# Epoch 00023: val_loss improved from 0.00671 to 0.00670, saving model to model_16.h5
# Epoch 24/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0070 - acc: 0.7211 - val_loss: 0.0067 - val_acc: 0.7380
#
# Epoch 00024: val_loss did not improve from 0.00670
# Epoch 25/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7219 - val_loss: 0.0067 - val_acc: 0.7386
#
# Epoch 00025: val_loss did not improve from 0.00670
# Epoch 26/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7216 - val_loss: 0.0067 - val_acc: 0.7379
#
# Epoch 00026: val_loss did not improve from 0.00670
# Epoch 27/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7214 - val_loss: 0.0067 - val_acc: 0.7364
#
# Epoch 00027: val_loss did not improve from 0.00670
# Epoch 28/100
# 24423/24423 [==============================] - 1308s 54ms/step - loss: 0.0070 - acc: 0.7210 - val_loss: 0.0067 - val_acc: 0.7381
#
# Epoch 00028: val_loss did not improve from 0.00670
# Epoch 29/100
# 24423/24423 [==============================] - 1307s 53ms/step - loss: 0.0070 - acc: 0.7223 - val_loss: 0.0067 - val_acc: 0.7375
#
# Epoch 00029: val_loss did not improve from 0.00670
# Epoch 30/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7223 - val_loss: 0.0067 - val_acc: 0.7367
#
# Epoch 00030: val_loss improved from 0.00670 to 0.00670, saving model to model_16.h5
# Epoch 31/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0070 - acc: 0.7216 - val_loss: 0.0067 - val_acc: 0.7412
#
# Epoch 00031: val_loss did not improve from 0.00670
# Epoch 32/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7213 - val_loss: 0.0067 - val_acc: 0.7379
#
# Epoch 00032: val_loss did not improve from 0.00670
# Epoch 33/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7214 - val_loss: 0.0067 - val_acc: 0.7405
#
# Epoch 00033: val_loss did not improve from 0.00670
# Epoch 34/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7218 - val_loss: 0.0067 - val_acc: 0.7390
#
# Epoch 00034: val_loss did not improve from 0.00670
# Epoch 35/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7212 - val_loss: 0.0067 - val_acc: 0.7385
#
# Epoch 00035: val_loss did not improve from 0.00670
# Epoch 36/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7224 - val_loss: 0.0067 - val_acc: 0.7423
#
# Epoch 00036: val_loss did not improve from 0.00670
# Epoch 37/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7220 - val_loss: 0.0067 - val_acc: 0.7387
#
# Epoch 00037: val_loss did not improve from 0.00670
# Epoch 38/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7230 - val_loss: 0.0067 - val_acc: 0.7372
#
# Epoch 00038: val_loss did not improve from 0.00670
# Epoch 39/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7226 - val_loss: 0.0067 - val_acc: 0.7386
#
# Epoch 00039: val_loss did not improve from 0.00670
# Epoch 40/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7222 - val_loss: 0.0067 - val_acc: 0.7410
#
# Epoch 00040: val_loss improved from 0.00670 to 0.00670, saving model to model_16.h5
# Epoch 41/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7225 - val_loss: 0.0067 - val_acc: 0.7414
#
# Epoch 00041: val_loss did not improve from 0.00670
# Epoch 42/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7223 - val_loss: 0.0067 - val_acc: 0.7386
#
# Epoch 00042: val_loss did not improve from 0.00670
# Epoch 43/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7225 - val_loss: 0.0067 - val_acc: 0.7392
#
# Epoch 00043: val_loss improved from 0.00670 to 0.00669, saving model to model_16.h5
# Epoch 44/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7222 - val_loss: 0.0067 - val_acc: 0.7381
#
# Epoch 00044: val_loss did not improve from 0.00669
# Epoch 45/100
# 24423/24423 [==============================] - 1301s 53ms/step - loss: 0.0070 - acc: 0.7226 - val_loss: 0.0067 - val_acc: 0.7388
#
# Epoch 00045: val_loss did not improve from 0.00669
# Epoch 46/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7231 - val_loss: 0.0067 - val_acc: 0.7375
#
# Epoch 00046: val_loss did not improve from 0.00669
# Epoch 47/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7237 - val_loss: 0.0067 - val_acc: 0.7392
#
# Epoch 00047: val_loss did not improve from 0.00669
# Epoch 48/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7229 - val_loss: 0.0067 - val_acc: 0.7439
#
# Epoch 00048: val_loss did not improve from 0.00669
# Epoch 49/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7227 - val_loss: 0.0067 - val_acc: 0.7420
#
# Epoch 00049: val_loss improved from 0.00669 to 0.00669, saving model to model_16.h5
# Epoch 50/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7233 - val_loss: 0.0067 - val_acc: 0.7379
#
# Epoch 00050: val_loss improved from 0.00669 to 0.00669, saving model to model_16.h5
# Epoch 51/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7228 - val_loss: 0.0067 - val_acc: 0.7393
#
# Epoch 00051: val_loss did not improve from 0.00669
# Epoch 52/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7236 - val_loss: 0.0067 - val_acc: 0.7380
#
# Epoch 00052: val_loss did not improve from 0.00669
# Epoch 53/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7239 - val_loss: 0.0067 - val_acc: 0.7401
#
# Epoch 00053: val_loss did not improve from 0.00669
# Epoch 54/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7237 - val_loss: 0.0067 - val_acc: 0.7415
#
# Epoch 00054: val_loss did not improve from 0.00669
# Epoch 55/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7237 - val_loss: 0.0067 - val_acc: 0.7406
#
# Epoch 00055: val_loss did not improve from 0.00669
# Epoch 56/100
# 24423/24423 [==============================] - 1301s 53ms/step - loss: 0.0070 - acc: 0.7232 - val_loss: 0.0067 - val_acc: 0.7403
#
# Epoch 00056: val_loss did not improve from 0.00669
# Epoch 57/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7240 - val_loss: 0.0067 - val_acc: 0.7435
#
# Epoch 00057: val_loss did not improve from 0.00669
# Epoch 58/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7236 - val_loss: 0.0067 - val_acc: 0.7415
#
# Epoch 00058: val_loss did not improve from 0.00669
# Epoch 59/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7238 - val_loss: 0.0067 - val_acc: 0.7406
#
# Epoch 00059: val_loss did not improve from 0.00669
# Epoch 60/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7246 - val_loss: 0.0067 - val_acc: 0.7414
#
# Epoch 00060: val_loss improved from 0.00669 to 0.00669, saving model to model_16.h5
# Epoch 61/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7249 - val_loss: 0.0067 - val_acc: 0.7418
#
# Epoch 00061: val_loss did not improve from 0.00669
# Epoch 62/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7240 - val_loss: 0.0067 - val_acc: 0.7389
#
# Epoch 00062: val_loss did not improve from 0.00669
# Epoch 63/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7247 - val_loss: 0.0067 - val_acc: 0.7397
#
# Epoch 00063: val_loss did not improve from 0.00669
# Epoch 64/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7241 - val_loss: 0.0067 - val_acc: 0.7385
#
# Epoch 00064: val_loss did not improve from 0.00669
# Epoch 65/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7239 - val_loss: 0.0067 - val_acc: 0.7406
#
# Epoch 00065: val_loss did not improve from 0.00669
# Epoch 66/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7240 - val_loss: 0.0067 - val_acc: 0.7421
#
# Epoch 00066: val_loss did not improve from 0.00669
# Epoch 67/100
# 24423/24423 [==============================] - 1302s 53ms/step - loss: 0.0070 - acc: 0.7254 - val_loss: 0.0067 - val_acc: 0.7429
#
# Epoch 00067: val_loss improved from 0.00669 to 0.00668, saving model to model_16.h5
# Epoch 68/100
# 24423/24423 [==============================] - 1303s 53ms/step - loss: 0.0070 - acc: 0.7245 - val_loss: 0.0067 - val_acc: 0.7428
#
# Epoch 00068: val_loss improved from 0.00668 to 0.00668, saving model to model_16.h5
# Epoch 69/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7243 - val_loss: 0.0067 - val_acc: 0.7395
#
# Epoch 00069: val_loss did not improve from 0.00668
# Epoch 70/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7248 - val_loss: 0.0067 - val_acc: 0.7402
#
# Epoch 00070: val_loss did not improve from 0.00668
# Epoch 71/100
# 24423/24423 [==============================] - 1307s 54ms/step - loss: 0.0070 - acc: 0.7248 - val_loss: 0.0067 - val_acc: 0.7439
#
# Epoch 00071: val_loss did not improve from 0.00668
# Epoch 72/100
# 24423/24423 [==============================] - 1307s 54ms/step - loss: 0.0070 - acc: 0.7248 - val_loss: 0.0067 - val_acc: 0.7411
#
# Epoch 00072: val_loss did not improve from 0.00668
# Epoch 73/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0070 - acc: 0.7245 - val_loss: 0.0067 - val_acc: 0.7419
#
# Epoch 00073: val_loss did not improve from 0.00668
# Epoch 74/100
# 24423/24423 [==============================] - 1305s 53ms/step - loss: 0.0070 - acc: 0.7252 - val_loss: 0.0067 - val_acc: 0.7409
#
# Epoch 00074: val_loss did not improve from 0.00668
# Epoch 75/100
# 24423/24423 [==============================] - 1306s 53ms/step - loss: 0.0070 - acc: 0.7249 - val_loss: 0.0067 - val_acc: 0.7399
#
# Epoch 00075: val_loss did not improve from 0.00668
# Epoch 76/100
# 24423/24423 [==============================] - 1307s 54ms/step - loss: 0.0070 - acc: 0.7244 - val_loss: 0.0067 - val_acc: 0.7417
#
# Epoch 00076: val_loss did not improve from 0.00668
# Epoch 77/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7251 - val_loss: 0.0067 - val_acc: 0.7405
#
# Epoch 00077: val_loss did not improve from 0.00668
# Epoch 78/100
# 24423/24423 [==============================] - 1304s 53ms/step - loss: 0.0070 - acc: 0.7246 - val_loss: 0.0067 - val_acc: 0.7410
#
# Epoch 00078: val_loss did not improve from 0.00668
# Epoch 00078: early stopping

# %%
loss = trainHistory.history['loss']
val_loss = trainHistory.history['val_loss']
epochsRange = range(len(trainHistory.history['loss']))
plt.figure()
plt.plot(epochsRange, loss, label='Training loss',color='g')
plt.plot(epochsRange, val_loss, label='Validation loss',color='b')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
plt.plot(trainHistory.history['acc'])
plt.plot(trainHistory.history['val_acc'])
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
print(trainHistory.history.keys())
# Out:
# dict_keys(['val_loss', 'lr', 'loss', 'acc', 'val_acc'])

# %%
pred = model.predict(X_test)

# %%
#plt.figure(figsize=(256, 256))
print("Test Images")

for i in range(20):
    #plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(pred[i])
    #plt.title("(Label: " + str(label_dict[curr_lbl]) + ")")
    plt.show()
# Out:
# Test Images
