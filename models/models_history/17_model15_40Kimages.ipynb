# %%
import os
import math
import random
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from skimage.io import imshow
#from sklearn.model_selection import train_test_split

#import tensorflow as tf

import keras

from keras.preprocessing.image import img_to_array, load_img
from keras.layers import Conv2D
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K

np.random.seed(1337)
# Out:
# Using TensorFlow backend.

# %%
#making sure GPU is in use 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1217651058264483657
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11285289370
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17963365467336521299
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Set some parameters
in_height = 64
in_width = 64
out_height = 256
out_width = 256
color_dim = 3
path_in = '/home/Matthew/image-super-resolution/data/imagenet/40k/res64noisy/'
path_out = '/home/Matthew/image-super-resolution/data/imagenet/40k/res256/'

# %%
#todo: add random shuffle . seed = 0

def load_images(path_in, path_out, test_size, valid_size):
    images = next(os.walk(path_in))[2] #oswalk is a generator 
    num_images = len(images)
  
    testSize  = int(test_size * num_images)
    validSize = int(valid_size * num_images)
    trainSize = int(math.ceil((1-(test_size+valid_size)) * num_images))
    
    X_train = np.zeros((trainSize,in_height,in_width,color_dim), dtype=np.float32)
    X_test = np.zeros((testSize,in_height,in_width,color_dim), dtype=np.float32)
    X_valid = np.zeros((validSize,in_height,in_width,color_dim), dtype=np.float32)

    y_train = np.zeros((trainSize,out_height,out_width,color_dim), dtype=np.float32)
    y_test  = np.zeros((testSize,out_height,out_width,color_dim), dtype=np.float32)
    y_valid  = np.zeros((validSize,out_height,out_width,color_dim), dtype=np.float32)
    
    trainIdx = 0
    testIdx = 0
    validIdx = 0
    for idx, image in enumerate(images):
        image_in_path = os.path.join(path_in,image)
        image_out_path = os.path.join(path_out,image)

        image_in_raw =  load_img(image_in_path, grayscale=False)
        image_out_raw = load_img(image_out_path, grayscale=False)

        #converts image to keras preprocessing image, then divide by 255 to un-invert the images
        image_in = (img_to_array(image_in_raw)).squeeze() / 255 
        image_out = (img_to_array(image_out_raw)).squeeze() / 255          
 
        try:
            if (idx % 1000 == 0):
                print("Stage " + str(idx))
        
            if (idx < testSize):
                #print("testIdx " + str(testIdx))
                X_test[testIdx] = image_in
                y_test[testIdx] = image_out
                testIdx+=1
                
            elif (idx < testSize + validSize):
                #print("validIdx " + str(validIdx))
                X_valid[validIdx] = image_in
                y_valid[validIdx] = image_out
                validIdx+=1
                
            else:
                #print("trainIdx " + str(trainIdx))
                X_train[trainIdx] = image_in
                y_train[trainIdx] = image_out
                trainIdx+=1
                
        except Exception as e: 
            print("\nERROR!!!!")
            print(image_in.shape)
            print(trainIdx)
            
            print(image_out.shape)
            print(testIdx)
            
            print("id "+str(idx))
            print(image_in_path)
            print(e)
           
            print("\n")
            
    return X_train,X_valid,X_test,y_train,y_valid,y_test

# %%
X_train,X_valid,X_test,y_train,y_valid,y_test = load_images(path_in, path_out, .2, .2)
# Out:
# Stage 0
# Stage 1000
# Stage 2000
# Stage 3000
# Stage 4000
# Stage 5000
# Stage 6000
# Stage 7000
# Stage 8000
# Stage 9000
# Stage 10000
# Stage 11000
# Stage 12000
# Stage 13000
# Stage 14000
# Stage 15000
# Stage 16000
# Stage 17000
# Stage 18000
# Stage 19000
# Stage 20000
# Stage 21000
# Stage 22000
# Stage 23000
# Stage 24000
# Stage 25000
# Stage 26000
# Stage 27000
# Stage 28000
# Stage 29000
# Stage 30000
# Stage 31000
# Stage 32000
# Stage 33000
# Stage 34000
# Stage 35000
# Stage 36000
# Stage 37000
# Stage 38000
# Stage 39000
# Stage 40000

# %%
print(len(X_train))
print(len(X_valid))
print(len(X_test))
# Out:
# 24423
# 8141
# 8141

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.core import Activation
from keras import backend as K
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
#https://github.com/zeoya/Keras-Super-Resolution/blob/master/myUtils/srcnn.py

# %%
#padding output size: see http://cs231n.github.io/convolutional-networks/
# output = (W−F+2P)/S+1   w- input size, f-kernel size, p-padding size

# %%
model = Sequential()
inputShape = (in_height, in_width, color_dim)
model.add(UpSampling2D((4,4),input_shape=inputShape))
model.add(Conv2D(32, (9, 9), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 32
model.add(Activation("relu"))
model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
model.add(Activation("relu"))
model.add(Conv2D(16, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
model.add(Activation("relu"))
model.add(Conv2D(color_dim, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 3
model.add(Activation("sigmoid"))

# %%
'''model = Sequential()
inputShape = (in_height, in_width, color_dim)
model.add(UpSampling2D((4,4),input_shape=inputShape))
model.add(Conv2D(32, (9, 9), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 32
model.add(Activation("relu"))
model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
model.add(Activation("relu"))
model.add(Conv2D(color_dim, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 3
model.add(Activation("sigmoid"))'''
# Out:
# 'model = Sequential()\ninputShape = (in_height, in_width, color_dim)\nmodel.add(UpSampling2D((4,4),input_shape=inputShape))\nmodel.add(Conv2D(32, (9, 9), padding=\'same\', kernel_initializer="he_normal")) # 256 X 256 X 32\nmodel.add(Activation("relu"))\nmodel.add(Conv2D(16, (7, 7), padding=\'same\', kernel_initializer="he_normal")) # 256 X 256 X 16\nmodel.add(Activation("relu"))\nmodel.add(Conv2D(color_dim, (5, 5), padding=\'same\', kernel_initializer="he_normal")) # 256 X 256 X 3\nmodel.add(Activation("sigmoid"))'

# %%
model.compile(loss='mean_squared_error', optimizer = RMSprop(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# up_sampling2d_1 (UpSampling2 (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      7808
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 16)      25104
# _________________________________________________________________
# activation_2 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 16)      6416
# _________________________________________________________________
# activation_3 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 256, 3)       1203
# _________________________________________________________________
# activation_4 (Activation)    (None, 256, 256, 3)       0
# =================================================================
# Total params: 40,531
# Trainable params: 40,531
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model_17.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
batch_size = 256
epochs = 30

trainHistory = model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_valid, y_valid),callbacks=callbacks)
# Out:
# Train on 24423 samples, validate on 8141 samples
# Epoch 1/30
# 24423/24423 [==============================] - 432s 18ms/step - loss: 0.0389 - acc: 0.5742 - val_loss: 0.0166 - val_acc: 0.6552
#
# Epoch 00001: val_loss improved from inf to 0.01656, saving model to model_15.h5
# Epoch 2/30
# 24423/24423 [==============================] - 400s 16ms/step - loss: 0.0226 - acc: 0.6515 - val_loss: 0.0179 - val_acc: 0.6406
#
# Epoch 00002: val_loss did not improve from 0.01656
# Epoch 3/30
# 24423/24423 [==============================] - 399s 16ms/step - loss: 0.0186 - acc: 0.6568 - val_loss: 0.0167 - val_acc: 0.6629
#
# Epoch 00003: val_loss did not improve from 0.01656
# Epoch 4/30
# 24423/24423 [==============================] - 398s 16ms/step - loss: 0.0164 - acc: 0.6619 - val_loss: 0.0133 - val_acc: 0.6749
#
# Epoch 00004: val_loss improved from 0.01656 to 0.01331, saving model to model_15.h5
# Epoch 5/30
# 24423/24423 [==============================] - 398s 16ms/step - loss: 0.0149 - acc: 0.6641 - val_loss: 0.0150 - val_acc: 0.6559
#
# Epoch 00005: val_loss did not improve from 0.01331
# Epoch 6/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0139 - acc: 0.6665 - val_loss: 0.0127 - val_acc: 0.6842
#
# Epoch 00006: val_loss improved from 0.01331 to 0.01272, saving model to model_15.h5
# Epoch 7/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0134 - acc: 0.6687 - val_loss: 0.0115 - val_acc: 0.6604
#
# Epoch 00007: val_loss improved from 0.01272 to 0.01152, saving model to model_15.h5
# Epoch 8/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0129 - acc: 0.6689 - val_loss: 0.0122 - val_acc: 0.6830
#
# Epoch 00008: val_loss did not improve from 0.01152
# Epoch 9/30
# 24423/24423 [==============================] - 396s 16ms/step - loss: 0.0124 - acc: 0.6714 - val_loss: 0.0109 - val_acc: 0.6784
#
# Epoch 00009: val_loss improved from 0.01152 to 0.01091, saving model to model_15.h5
# Epoch 10/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0122 - acc: 0.6705 - val_loss: 0.0117 - val_acc: 0.6401
#
# Epoch 00010: val_loss did not improve from 0.01091
# Epoch 11/30
# 24423/24423 [==============================] - 396s 16ms/step - loss: 0.0119 - acc: 0.6734 - val_loss: 0.0118 - val_acc: 0.6407
#
# Epoch 00011: val_loss did not improve from 0.01091
# Epoch 12/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0116 - acc: 0.6748 - val_loss: 0.0100 - val_acc: 0.6642
#
# Epoch 00012: val_loss improved from 0.01091 to 0.00997, saving model to model_15.h5
# Epoch 13/30
# 24423/24423 [==============================] - 396s 16ms/step - loss: 0.0115 - acc: 0.6763 - val_loss: 0.0117 - val_acc: 0.6877
#
# Epoch 00013: val_loss did not improve from 0.00997
# Epoch 14/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0113 - acc: 0.6745 - val_loss: 0.0101 - val_acc: 0.6992
#
# Epoch 00014: val_loss did not improve from 0.00997
# Epoch 15/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0113 - acc: 0.6743 - val_loss: 0.0112 - val_acc: 0.6807
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.00997
# Epoch 16/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0081 - acc: 0.7075 - val_loss: 0.0078 - val_acc: 0.7096
#
# Epoch 00016: val_loss improved from 0.00997 to 0.00781, saving model to model_15.h5
# Epoch 17/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0078 - acc: 0.7128 - val_loss: 0.0078 - val_acc: 0.7145
#
# Epoch 00017: val_loss improved from 0.00781 to 0.00775, saving model to model_15.h5
# Epoch 18/30
# 24423/24423 [==============================] - 398s 16ms/step - loss: 0.0077 - acc: 0.7144 - val_loss: 0.0076 - val_acc: 0.7123
#
# Epoch 00018: val_loss improved from 0.00775 to 0.00764, saving model to model_15.h5
# Epoch 19/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0076 - acc: 0.7161 - val_loss: 0.0077 - val_acc: 0.7128
#
# Epoch 00019: val_loss did not improve from 0.00764
# Epoch 20/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0076 - acc: 0.7171 - val_loss: 0.0075 - val_acc: 0.7159
#
# Epoch 00020: val_loss improved from 0.00764 to 0.00752, saving model to model_15.h5
# Epoch 21/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0075 - acc: 0.7180 - val_loss: 0.0075 - val_acc: 0.7115
#
# Epoch 00021: val_loss did not improve from 0.00752
# Epoch 22/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0075 - acc: 0.7188 - val_loss: 0.0075 - val_acc: 0.7120
#
# Epoch 00022: val_loss improved from 0.00752 to 0.00746, saving model to model_15.h5
# Epoch 23/30
# 24423/24423 [==============================] - 398s 16ms/step - loss: 0.0075 - acc: 0.7195 - val_loss: 0.0074 - val_acc: 0.7167
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00023: val_loss improved from 0.00746 to 0.00742, saving model to model_15.h5
# Epoch 24/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0074 - acc: 0.7201 - val_loss: 0.0074 - val_acc: 0.7170
#
# Epoch 00024: val_loss improved from 0.00742 to 0.00737, saving model to model_15.h5
# Epoch 25/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0074 - acc: 0.7201 - val_loss: 0.0074 - val_acc: 0.7169
#
# Epoch 00025: val_loss improved from 0.00737 to 0.00736, saving model to model_15.h5
# Epoch 26/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0074 - acc: 0.7202 - val_loss: 0.0073 - val_acc: 0.7174
#
# Epoch 00026: val_loss improved from 0.00736 to 0.00735, saving model to model_15.h5
# Epoch 27/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0074 - acc: 0.7202 - val_loss: 0.0073 - val_acc: 0.7175
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00027: val_loss improved from 0.00735 to 0.00734, saving model to model_15.h5
# Epoch 28/30
# 24423/24423 [==============================] - 398s 16ms/step - loss: 0.0074 - acc: 0.7203 - val_loss: 0.0073 - val_acc: 0.7171
#
# Epoch 00028: val_loss improved from 0.00734 to 0.00733, saving model to model_15.h5
# Epoch 29/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0074 - acc: 0.7202 - val_loss: 0.0073 - val_acc: 0.7166
#
# Epoch 00029: val_loss improved from 0.00733 to 0.00732, saving model to model_15.h5
# Epoch 30/30
# 24423/24423 [==============================] - 397s 16ms/step - loss: 0.0073 - acc: 0.7204 - val_loss: 0.0073 - val_acc: 0.7166
#
# Epoch 00030: val_loss improved from 0.00732 to 0.00732, saving model to model_15.h5

# %%
loss = trainHistory.history['loss']
val_loss = trainHistory.history['val_loss']
epochsRange = range(len(trainHistory.history['loss']))
plt.figure()
plt.plot(epochsRange, loss, label='Training loss',color='g')
plt.plot(epochsRange, val_loss, label='Validation loss',color='b')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
plt.plot(trainHistory.history['acc'])
plt.plot(trainHistory.history['val_acc'])
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
print(trainHistory.history.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
pred = model.predict(X_test)

# %%
#plt.figure(figsize=(256, 256))
print("Test Images")

for i in range(20):
    #plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(pred[i])
    #curr_lbl = y_test[i]
    #plt.title("(Label: " + str(label_dict[curr_lbl]) + ")")
    plt.show()
#plt.figure(figsize=(256, 256))
#print("Reconstruction of Test Images")
#for i in range(10):
    #plt.subplot(2, 10, i+1)
    #plt.imshow(pred[i])  
    #plt.show()
# Out:
# Test Images

# %%
plt.imshow(pred[0])
