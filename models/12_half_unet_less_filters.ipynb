# %%
import os
import math
import random
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from skimage.io import imshow
#from sklearn.model_selection import train_test_split

#import tensorflow as tf

import keras

from keras.preprocessing.image import img_to_array, load_img
from keras.layers import Conv2D
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K

np.random.seed(1337)
# Out:
# Using TensorFlow backend.

# %%
#making sure GPU is in use 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1577763589033305306
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11285289370
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11154099274223330636
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Set some parameters
in_height = 64
in_width = 64
out_height = 256
out_width = 256
color_dim = 3
path_in = '/home/Matthew/image-super-resolution/data/imagenet/10k/res64noisy/'
path_out = '/home/Matthew/image-super-resolution/data/imagenet/10k/res256/'

# %%
#todo: add random shuffle 
#, seed = 0

def load_images(path_in, path_out, test_size):
    images = next(os.walk(path_in))[2] #oswalk is a generator 
    num_images = len(images)

    splitIdx = int(test_size * num_images)
    testSize = int((test_size) * num_images)
    trainSize = int(math.ceil((1-test_size) * num_images))
    
    X_train = np.zeros((trainSize,in_height,in_width,color_dim), dtype=np.float32)
    X_test = np.zeros((testSize,in_height,in_width,color_dim), dtype=np.float32)
    y_train = np.zeros((trainSize,out_height,out_width,color_dim), dtype=np.float32)
    y_test  = np.zeros((testSize,out_height,out_width,color_dim), dtype=np.float32)

    trainIdx = 0
    testIdx = 0
    for idx, image in enumerate(images):
        image_in_path = os.path.join(path_in,image)
        image_out_path = os.path.join(path_out,image)

        image_in_raw =  load_img(image_in_path, grayscale=False)
        image_out_raw = load_img(image_out_path, grayscale=False)

        #converts image to keras preprocessing image, then divide by 255 to un-invert the images
        image_in = (img_to_array(image_in_raw)).squeeze() / 255 
        image_out = (img_to_array(image_out_raw)).squeeze() / 255          
 
        try:
            if (idx % 1000 == 0):
                print("Stage " + str(idx))
        
            if (idx >= splitIdx):
                #print("trainIdx " + str(trainIdx))
                X_train[trainIdx] = image_in
                y_train[trainIdx] = image_out
                
                trainIdx+=1
            else:
                #print("testIdx " + str(testIdx))
                X_test[testIdx] = image_in
                y_test[testIdx] = image_out
                
                testIdx+=1
                
        except Exception as e: 
            print("\nERROR!!!!")
            print(image_in.shape)
            print(trainIdx)
            
            print(image_out.shape)
            print(testIdx)
            
            print("id "+str(idx))
            print(image_in_path)
            print(e)
           
            print("\n")
            
    return X_train,X_test,y_train,y_test

# %%
X_train,X_test,y_train,y_test = load_images(path_in, path_out, .2)
# Out:
# Stage 0
# Stage 1000
# Stage 2000
# Stage 3000
# Stage 4000
# Stage 5000
# Stage 6000
# Stage 7000
# Stage 8000
# Stage 9000

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.core import Activation
from keras import backend as K
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from keras.optimizers import RMSprop

# %%
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers import  BatchNormalization, Activation, Dropout, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
#padding output size: see http://cs231n.github.io/convolutional-networks/
# output = (W−F+2P)/S+1   w- input size, f-kernel size, p-padding size

# %%
#model = Sequential()
#inputShape = (in_height, in_width, color_dim)
#model.add(UpSampling2D((4,4),input_shape=inputShape))
#model.add(Conv2D(32, (9, 9), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 32
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(color_dim, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 3
#model.add(Activation("sigmoid"))

# %%
# https://www.depends-on-the-definition.com/unet-keras-segmenting-images/

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    
    #u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    #u9 = Dropout(dropout)(u9)
    #c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c8)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
'''def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model'''
# Out:
# "def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):\n    # contracting path\n    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    \n    # expansive path\n    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)\n    u6 = Dropout(dropout)(u6)\n    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)\n\n    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)\n    u7 = Dropout(dropout)(u7)\n    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)\n\n    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)\n    u8 = Dropout(dropout)(u8)\n    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)\n\n    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)\n    u9 = Dropout(dropout)(u9)\n    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)\n    model = Model(inputs=[input_img], outputs=[outputs])\n    return model"

# %%
input_img = Input((in_height, in_width, color_dim), name='img')
model = create_network(input_img, n_filters=2, dropout=0.05, batchnorm=True)

# %%
model.compile(loss='mean_squared_error', optimizer = RMSprop(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 128, 128, 16)      448
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 128, 128, 16)      2320
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128, 128, 16)      64
# _________________________________________________________________
# activation_13 (Activation)   (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 128, 128, 16)      2320
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128, 128, 16)      64
# _________________________________________________________________
# activation_14 (Activation)   (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 256, 256, 8)       1160
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_15 (Activation)   (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_16 (Activation)   (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_transpose_9 (Conv2DTr (None, 256, 256, 4)       292
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256, 256, 4)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 256, 256, 4)       148
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256, 256, 4)       16
# _________________________________________________________________
# activation_17 (Activation)   (None, 256, 256, 4)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 256, 256, 4)       148
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256, 256, 4)       16
# _________________________________________________________________
# activation_18 (Activation)   (None, 256, 256, 4)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 256, 256, 3)       15
# =================================================================
# Total params: 8,243
# Trainable params: 8,131
# Non-trainable params: 112
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
batch_size = 256
epochs = 100
trainHistory = model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_test, y_test),callbacks=callbacks)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0344 - acc: 0.3974 - val_loss: 0.0308 - val_acc: 0.4172
#
# Epoch 00001: val_loss improved from inf to 0.03077, saving model to model-tgs-salt.h5
# Epoch 2/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0300 - acc: 0.4033 - val_loss: 0.0262 - val_acc: 0.4064
#
# Epoch 00002: val_loss improved from 0.03077 to 0.02621, saving model to model-tgs-salt.h5
# Epoch 3/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0262 - acc: 0.4112 - val_loss: 0.0228 - val_acc: 0.4282
#
# Epoch 00003: val_loss improved from 0.02621 to 0.02284, saving model to model-tgs-salt.h5
# Epoch 4/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0228 - acc: 0.4218 - val_loss: 0.0199 - val_acc: 0.4368
#
# Epoch 00004: val_loss improved from 0.02284 to 0.01993, saving model to model-tgs-salt.h5
# Epoch 5/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0200 - acc: 0.4348 - val_loss: 0.0181 - val_acc: 0.4471
#
# Epoch 00005: val_loss improved from 0.01993 to 0.01808, saving model to model-tgs-salt.h5
# Epoch 6/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0177 - acc: 0.4487 - val_loss: 0.0174 - val_acc: 0.4566
#
# Epoch 00006: val_loss improved from 0.01808 to 0.01737, saving model to model-tgs-salt.h5
# Epoch 7/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0160 - acc: 0.4621 - val_loss: 0.0148 - val_acc: 0.4487
#
# Epoch 00007: val_loss improved from 0.01737 to 0.01482, saving model to model-tgs-salt.h5
# Epoch 8/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0146 - acc: 0.4761 - val_loss: 0.0137 - val_acc: 0.4882
#
# Epoch 00008: val_loss improved from 0.01482 to 0.01371, saving model to model-tgs-salt.h5
# Epoch 9/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0135 - acc: 0.4907 - val_loss: 0.0131 - val_acc: 0.4870
#
# Epoch 00009: val_loss improved from 0.01371 to 0.01305, saving model to model-tgs-salt.h5
# Epoch 10/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0127 - acc: 0.5058 - val_loss: 0.0127 - val_acc: 0.5216
#
# Epoch 00010: val_loss improved from 0.01305 to 0.01273, saving model to model-tgs-salt.h5
# Epoch 11/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0121 - acc: 0.5193 - val_loss: 0.0117 - val_acc: 0.5263
#
# Epoch 00011: val_loss improved from 0.01273 to 0.01169, saving model to model-tgs-salt.h5
# Epoch 12/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0116 - acc: 0.5297 - val_loss: 0.0119 - val_acc: 0.5334
#
# Epoch 00012: val_loss did not improve from 0.01169
# Epoch 13/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0112 - acc: 0.5400 - val_loss: 0.0116 - val_acc: 0.5363
#
# Epoch 00013: val_loss improved from 0.01169 to 0.01164, saving model to model-tgs-salt.h5
# Epoch 14/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0109 - acc: 0.5494 - val_loss: 0.0115 - val_acc: 0.5280
#
# Epoch 00014: val_loss improved from 0.01164 to 0.01152, saving model to model-tgs-salt.h5
# Epoch 15/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0107 - acc: 0.5589 - val_loss: 0.0121 - val_acc: 0.5116
#
# Epoch 00015: val_loss did not improve from 0.01152
# Epoch 16/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0104 - acc: 0.5659 - val_loss: 0.0114 - val_acc: 0.5454
#
# Epoch 00016: val_loss improved from 0.01152 to 0.01145, saving model to model-tgs-salt.h5
# Epoch 17/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0103 - acc: 0.5742 - val_loss: 0.0106 - val_acc: 0.5765
#
# Epoch 00017: val_loss improved from 0.01145 to 0.01058, saving model to model-tgs-salt.h5
# Epoch 18/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0101 - acc: 0.5810 - val_loss: 0.0102 - val_acc: 0.5875
#
# Epoch 00018: val_loss improved from 0.01058 to 0.01020, saving model to model-tgs-salt.h5
# Epoch 19/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0100 - acc: 0.5885 - val_loss: 0.0098 - val_acc: 0.6031
#
# Epoch 00019: val_loss improved from 0.01020 to 0.00983, saving model to model-tgs-salt.h5
# Epoch 20/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0099 - acc: 0.5906 - val_loss: 0.0105 - val_acc: 0.5719
#
# Epoch 00020: val_loss did not improve from 0.00983
# Epoch 21/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0098 - acc: 0.5965 - val_loss: 0.0099 - val_acc: 0.5798
#
# Epoch 00021: val_loss did not improve from 0.00983
# Epoch 22/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0097 - acc: 0.6004 - val_loss: 0.0109 - val_acc: 0.5667
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00022: val_loss did not improve from 0.00983
# Epoch 23/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0096 - acc: 0.5995 - val_loss: 0.0093 - val_acc: 0.6099
#
# Epoch 00023: val_loss improved from 0.00983 to 0.00931, saving model to model-tgs-salt.h5
# Epoch 24/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6051 - val_loss: 0.0092 - val_acc: 0.6181
#
# Epoch 00024: val_loss improved from 0.00931 to 0.00922, saving model to model-tgs-salt.h5
# Epoch 25/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0095 - acc: 0.6058 - val_loss: 0.0092 - val_acc: 0.6169
#
# Epoch 00025: val_loss improved from 0.00922 to 0.00916, saving model to model-tgs-salt.h5
# Epoch 26/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6058 - val_loss: 0.0091 - val_acc: 0.6203
#
# Epoch 00026: val_loss improved from 0.00916 to 0.00914, saving model to model-tgs-salt.h5
# Epoch 27/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6069 - val_loss: 0.0091 - val_acc: 0.6203
#
# Epoch 00027: val_loss improved from 0.00914 to 0.00909, saving model to model-tgs-salt.h5
# Epoch 28/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6078 - val_loss: 0.0091 - val_acc: 0.6202
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00028: val_loss did not improve from 0.00909
# Epoch 29/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6070 - val_loss: 0.0090 - val_acc: 0.6230
#
# Epoch 00029: val_loss improved from 0.00909 to 0.00905, saving model to model-tgs-salt.h5
# Epoch 30/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6077 - val_loss: 0.0090 - val_acc: 0.6239
#
# Epoch 00030: val_loss improved from 0.00905 to 0.00903, saving model to model-tgs-salt.h5
# Epoch 31/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6087 - val_loss: 0.0090 - val_acc: 0.6242
#
# Epoch 00031: val_loss improved from 0.00903 to 0.00902, saving model to model-tgs-salt.h5
# Epoch 32/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6078 - val_loss: 0.0090 - val_acc: 0.6244
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00032: val_loss improved from 0.00902 to 0.00902, saving model to model-tgs-salt.h5
# Epoch 33/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6083 - val_loss: 0.0090 - val_acc: 0.6251
#
# Epoch 00033: val_loss improved from 0.00902 to 0.00901, saving model to model-tgs-salt.h5
# Epoch 34/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6080 - val_loss: 0.0090 - val_acc: 0.6251
#
# Epoch 00034: val_loss did not improve from 0.00901
# Epoch 35/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6087 - val_loss: 0.0090 - val_acc: 0.6254
#
# Epoch 00035: val_loss did not improve from 0.00901
# Epoch 36/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6087 - val_loss: 0.0090 - val_acc: 0.6254
#
# Epoch 00036: val_loss improved from 0.00901 to 0.00901, saving model to model-tgs-salt.h5
# Epoch 37/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6083 - val_loss: 0.0090 - val_acc: 0.6254
#
# Epoch 00037: val_loss improved from 0.00901 to 0.00900, saving model to model-tgs-salt.h5
# Epoch 38/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6090 - val_loss: 0.0090 - val_acc: 0.6260
#
# Epoch 00038: val_loss did not improve from 0.00900
# Epoch 39/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6082 - val_loss: 0.0090 - val_acc: 0.6259
#
# Epoch 00039: val_loss improved from 0.00900 to 0.00900, saving model to model-tgs-salt.h5
# Epoch 40/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6083 - val_loss: 0.0090 - val_acc: 0.6255
#
# Epoch 00040: val_loss improved from 0.00900 to 0.00899, saving model to model-tgs-salt.h5
# Epoch 41/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6091 - val_loss: 0.0090 - val_acc: 0.6259
#
# Epoch 00041: val_loss did not improve from 0.00899
# Epoch 42/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6093 - val_loss: 0.0090 - val_acc: 0.6260
#
# Epoch 00042: val_loss improved from 0.00899 to 0.00899, saving model to model-tgs-salt.h5
# Epoch 43/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6094 - val_loss: 0.0090 - val_acc: 0.6258
#
# Epoch 00043: val_loss improved from 0.00899 to 0.00899, saving model to model-tgs-salt.h5
# Epoch 44/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6088 - val_loss: 0.0090 - val_acc: 0.6261
#
# Epoch 00044: val_loss improved from 0.00899 to 0.00899, saving model to model-tgs-salt.h5
# Epoch 45/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6092 - val_loss: 0.0090 - val_acc: 0.6262
#
# Epoch 00045: val_loss did not improve from 0.00899
# Epoch 46/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6095 - val_loss: 0.0090 - val_acc: 0.6261
#
# Epoch 00046: val_loss improved from 0.00899 to 0.00899, saving model to model-tgs-salt.h5
# Epoch 47/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6090 - val_loss: 0.0090 - val_acc: 0.6260
#
# Epoch 00047: val_loss improved from 0.00899 to 0.00898, saving model to model-tgs-salt.h5
# Epoch 48/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6096 - val_loss: 0.0090 - val_acc: 0.6266
#
# Epoch 00048: val_loss did not improve from 0.00898
# Epoch 49/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6095 - val_loss: 0.0090 - val_acc: 0.6266
#
# Epoch 00049: val_loss did not improve from 0.00898
# Epoch 50/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6091 - val_loss: 0.0090 - val_acc: 0.6262
#
# Epoch 00050: val_loss improved from 0.00898 to 0.00898, saving model to model-tgs-salt.h5
# Epoch 51/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6097 - val_loss: 0.0090 - val_acc: 0.6262
#
# Epoch 00051: val_loss improved from 0.00898 to 0.00898, saving model to model-tgs-salt.h5
# Epoch 52/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6099 - val_loss: 0.0090 - val_acc: 0.6263
#
# Epoch 00052: val_loss did not improve from 0.00898
# Epoch 53/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6095 - val_loss: 0.0090 - val_acc: 0.6265
#
# Epoch 00053: val_loss improved from 0.00898 to 0.00898, saving model to model-tgs-salt.h5
# Epoch 54/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6101 - val_loss: 0.0090 - val_acc: 0.6265
#
# Epoch 00054: val_loss did not improve from 0.00898
# Epoch 55/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6099 - val_loss: 0.0090 - val_acc: 0.6267
#
# Epoch 00055: val_loss improved from 0.00898 to 0.00898, saving model to model-tgs-salt.h5
# Epoch 56/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6102 - val_loss: 0.0090 - val_acc: 0.6268
#
# Epoch 00056: val_loss improved from 0.00898 to 0.00897, saving model to model-tgs-salt.h5
# Epoch 57/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6095 - val_loss: 0.0090 - val_acc: 0.6269
#
# Epoch 00057: val_loss improved from 0.00897 to 0.00897, saving model to model-tgs-salt.h5
# Epoch 58/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6103 - val_loss: 0.0090 - val_acc: 0.6266
#
# Epoch 00058: val_loss improved from 0.00897 to 0.00897, saving model to model-tgs-salt.h5
# Epoch 59/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6093 - val_loss: 0.0090 - val_acc: 0.6271
#
# Epoch 00059: val_loss did not improve from 0.00897
# Epoch 60/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6101 - val_loss: 0.0090 - val_acc: 0.6272
#
# Epoch 00060: val_loss improved from 0.00897 to 0.00897, saving model to model-tgs-salt.h5
# Epoch 61/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6107 - val_loss: 0.0090 - val_acc: 0.6270
#
# Epoch 00061: val_loss improved from 0.00897 to 0.00897, saving model to model-tgs-salt.h5
# Epoch 62/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6095 - val_loss: 0.0090 - val_acc: 0.6271
#
# Epoch 00062: val_loss improved from 0.00897 to 0.00897, saving model to model-tgs-salt.h5
# Epoch 63/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0094 - acc: 0.6103 - val_loss: 0.0090 - val_acc: 0.6270
#
# Epoch 00063: val_loss improved from 0.00897 to 0.00896, saving model to model-tgs-salt.h5
# Epoch 64/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6112 - val_loss: 0.0090 - val_acc: 0.6270
#
# Epoch 00064: val_loss did not improve from 0.00896
# Epoch 65/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6101 - val_loss: 0.0090 - val_acc: 0.6271
#
# Epoch 00065: val_loss improved from 0.00896 to 0.00896, saving model to model-tgs-salt.h5
# Epoch 66/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6108 - val_loss: 0.0090 - val_acc: 0.6270
#
# Epoch 00066: val_loss improved from 0.00896 to 0.00896, saving model to model-tgs-salt.h5
# Epoch 67/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6103 - val_loss: 0.0090 - val_acc: 0.6273
#
# Epoch 00067: val_loss improved from 0.00896 to 0.00896, saving model to model-tgs-salt.h5
# Epoch 68/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6109 - val_loss: 0.0090 - val_acc: 0.6274
#
# Epoch 00068: val_loss improved from 0.00896 to 0.00896, saving model to model-tgs-salt.h5
# Epoch 69/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6110 - val_loss: 0.0090 - val_acc: 0.6276
#
# Epoch 00069: val_loss did not improve from 0.00896
# Epoch 70/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6109 - val_loss: 0.0090 - val_acc: 0.6275
#
# Epoch 00070: val_loss improved from 0.00896 to 0.00895, saving model to model-tgs-salt.h5
# Epoch 71/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6108 - val_loss: 0.0090 - val_acc: 0.6275
#
# Epoch 00071: val_loss improved from 0.00895 to 0.00895, saving model to model-tgs-salt.h5
# Epoch 72/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6108 - val_loss: 0.0090 - val_acc: 0.6278
#
# Epoch 00072: val_loss improved from 0.00895 to 0.00895, saving model to model-tgs-salt.h5
# Epoch 73/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6115 - val_loss: 0.0090 - val_acc: 0.6277
#
# Epoch 00073: val_loss did not improve from 0.00895
# Epoch 74/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6113 - val_loss: 0.0089 - val_acc: 0.6275
#
# Epoch 00074: val_loss improved from 0.00895 to 0.00895, saving model to model-tgs-salt.h5
# Epoch 75/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6106 - val_loss: 0.0089 - val_acc: 0.6277
#
# Epoch 00075: val_loss did not improve from 0.00895
# Epoch 76/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6115 - val_loss: 0.0090 - val_acc: 0.6282
#
# Epoch 00076: val_loss did not improve from 0.00895
# Epoch 77/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6113 - val_loss: 0.0089 - val_acc: 0.6280
#
# Epoch 00077: val_loss improved from 0.00895 to 0.00895, saving model to model-tgs-salt.h5
# Epoch 78/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6107 - val_loss: 0.0090 - val_acc: 0.6282
#
# Epoch 00078: val_loss did not improve from 0.00895
# Epoch 79/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6111 - val_loss: 0.0089 - val_acc: 0.6281
#
# Epoch 00079: val_loss improved from 0.00895 to 0.00895, saving model to model-tgs-salt.h5
# Epoch 80/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6112 - val_loss: 0.0089 - val_acc: 0.6280
#
# Epoch 00080: val_loss improved from 0.00895 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 81/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6115 - val_loss: 0.0089 - val_acc: 0.6281
#
# Epoch 00081: val_loss improved from 0.00894 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 82/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6118 - val_loss: 0.0089 - val_acc: 0.6283
#
# Epoch 00082: val_loss did not improve from 0.00894
# Epoch 83/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0094 - acc: 0.6117 - val_loss: 0.0089 - val_acc: 0.6283
#
# Epoch 00083: val_loss improved from 0.00894 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 84/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6121 - val_loss: 0.0089 - val_acc: 0.6281
#
# Epoch 00084: val_loss improved from 0.00894 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 85/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6120 - val_loss: 0.0089 - val_acc: 0.6282
#
# Epoch 00085: val_loss improved from 0.00894 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 86/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6119 - val_loss: 0.0089 - val_acc: 0.6284
#
# Epoch 00086: val_loss improved from 0.00894 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 87/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6122 - val_loss: 0.0089 - val_acc: 0.6284
#
# Epoch 00087: val_loss improved from 0.00894 to 0.00894, saving model to model-tgs-salt.h5
# Epoch 88/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6119 - val_loss: 0.0089 - val_acc: 0.6285
#
# Epoch 00088: val_loss improved from 0.00894 to 0.00893, saving model to model-tgs-salt.h5
# Epoch 89/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6123 - val_loss: 0.0089 - val_acc: 0.6288
#
# Epoch 00089: val_loss did not improve from 0.00893
# Epoch 90/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6121 - val_loss: 0.0089 - val_acc: 0.6288
#
# Epoch 00090: val_loss did not improve from 0.00893
# Epoch 91/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6119 - val_loss: 0.0089 - val_acc: 0.6287
#
# Epoch 00091: val_loss improved from 0.00893 to 0.00893, saving model to model-tgs-salt.h5
# Epoch 92/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6116 - val_loss: 0.0089 - val_acc: 0.6289
#
# Epoch 00092: val_loss did not improve from 0.00893
# Epoch 93/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6120 - val_loss: 0.0089 - val_acc: 0.6289
#
# Epoch 00093: val_loss improved from 0.00893 to 0.00893, saving model to model-tgs-salt.h5
# Epoch 94/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6125 - val_loss: 0.0089 - val_acc: 0.6292
#
# Epoch 00094: val_loss did not improve from 0.00893
# Epoch 95/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6126 - val_loss: 0.0089 - val_acc: 0.6290
#
# Epoch 00095: val_loss improved from 0.00893 to 0.00893, saving model to model-tgs-salt.h5
# Epoch 96/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6117 - val_loss: 0.0089 - val_acc: 0.6291
#
# Epoch 00096: val_loss did not improve from 0.00893
# Epoch 97/100
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.0093 - acc: 0.6125 - val_loss: 0.0089 - val_acc: 0.6289
#
# Epoch 00097: val_loss improved from 0.00893 to 0.00892, saving model to model-tgs-salt.h5
# Epoch 98/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6124 - val_loss: 0.0089 - val_acc: 0.6292
#
# Epoch 00098: val_loss did not improve from 0.00892
# Epoch 99/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6132 - val_loss: 0.0089 - val_acc: 0.6292
#
# Epoch 00099: val_loss improved from 0.00892 to 0.00892, saving model to model-tgs-salt.h5
# Epoch 100/100
# 8000/8000 [==============================] - 81s 10ms/step - loss: 0.0093 - acc: 0.6128 - val_loss: 0.0089 - val_acc: 0.6295
#
# Epoch 00100: val_loss improved from 0.00892 to 0.00892, saving model to model-tgs-salt.h5

# %%
loss = trainHistory.history['loss']
val_loss = trainHistory.history['val_loss']
epochsRange = range(epochs)
plt.figure()
plt.plot(epochsRange, loss, label='Training loss',color='g')
plt.plot(epochsRange, val_loss, label='Validation loss',color='b')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
plt.plot(trainHistory.history['acc'])
plt.plot(trainHistory.history['val_acc'])
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
print(trainHistory.history.keys())
# Out:
# dict_keys(['val_loss', 'loss', 'acc', 'val_acc', 'lr'])

# %%
pred = model.predict(X_test)

# %%
#plt.figure(figsize=(256, 256))
print("Test Images")

for i in range(10):
    #plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(pred[i])
    #plt.title("(Label: " + str(label_dict[curr_lbl]) + ")")
    plt.show()
# Out:
# Test Images

# %%
plt.imshow(pred[0])
