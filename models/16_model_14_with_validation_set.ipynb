# %%
import os
import math
import random
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from skimage.io import imshow
#from sklearn.model_selection import train_test_split

#import tensorflow as tf

import keras

from keras.preprocessing.image import img_to_array, load_img
from keras.layers import Conv2D
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K

np.random.seed(1337)
# Out:
# Using TensorFlow backend.

# %%
#making sure GPU is in use 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17564803304162027473
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11285289370
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9532341343414843915
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Set some parameters
in_height = 64
in_width = 64
out_height = 256
out_width = 256
color_dim = 3
path_in = '/home/Matthew/image-super-resolution/data/imagenet/10k/res64noisy/'
path_out = '/home/Matthew/image-super-resolution/data/imagenet/10k/res256/'

# %%
#todo: add random shuffle . seed = 0

def load_images(path_in, path_out, test_size, valid_size):
    images = next(os.walk(path_in))[2] #oswalk is a generator 
    num_images = len(images)
  
    testSize  = int(test_size * num_images)
    validSize = int(valid_size * num_images)
    trainSize = int(math.ceil((1-(test_size+valid_size)) * num_images))
    
    X_train = np.zeros((trainSize,in_height,in_width,color_dim), dtype=np.float32)
    X_test = np.zeros((testSize,in_height,in_width,color_dim), dtype=np.float32)
    X_valid = np.zeros((validSize,in_height,in_width,color_dim), dtype=np.float32)

    y_train = np.zeros((trainSize,out_height,out_width,color_dim), dtype=np.float32)
    y_test  = np.zeros((testSize,out_height,out_width,color_dim), dtype=np.float32)
    y_valid  = np.zeros((validSize,out_height,out_width,color_dim), dtype=np.float32)
    
    trainIdx = 0
    testIdx = 0
    validIdx = 0
    for idx, image in enumerate(images):
        image_in_path = os.path.join(path_in,image)
        image_out_path = os.path.join(path_out,image)

        image_in_raw =  load_img(image_in_path, grayscale=False)
        image_out_raw = load_img(image_out_path, grayscale=False)

        #converts image to keras preprocessing image, then divide by 255 to un-invert the images
        image_in = (img_to_array(image_in_raw)).squeeze() / 255 
        image_out = (img_to_array(image_out_raw)).squeeze() / 255          
 
        try:
            if (idx % 1000 == 0):
                print("Stage " + str(idx))
        
            if (idx < testSize):
                #print("testIdx " + str(testIdx))
                X_test[testIdx] = image_in
                y_test[testIdx] = image_out
                testIdx+=1
                
            elif (idx < validSize + validSize):
                #print("validIdx " + str(validIdx))
                X_valid[validIdx] = image_in
                y_valid[validIdx] = image_out
                validIdx+=1
                
            else:
                #print("trainIdx " + str(trainIdx))
                X_train[trainIdx] = image_in
                y_train[trainIdx] = image_out
                trainIdx+=1
                
        except Exception as e: 
            print("\nERROR!!!!")
            print(image_in.shape)
            print(trainIdx)
            
            print(image_out.shape)
            print(testIdx)
            
            print("id "+str(idx))
            print(image_in_path)
            print(e)
           
            print("\n")
            
    return X_train,X_valid,X_test,y_train,y_valid,y_test

# %%
X_train,X_valid,X_test,y_train,y_valid,y_test = load_images(path_in, path_out, .2, .2)
# Out:
# Stage 0
# Stage 1000
# Stage 2000
# Stage 3000
# Stage 4000
# Stage 5000
# Stage 6000
# Stage 7000
# Stage 8000
# Stage 9000

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.core import Activation
from keras import backend as K
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from keras.optimizers import RMSprop

# %%
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers import  BatchNormalization, Activation, Dropout, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
#padding output size: see http://cs231n.github.io/convolutional-networks/
# output = (W−F+2P)/S+1   w- input size, f-kernel size, p-padding size

# %%
#model = Sequential()
#inputShape = (in_height, in_width, color_dim)
#model.add(UpSampling2D((4,4),input_shape=inputShape))
#model.add(Conv2D(32, (9, 9), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 32
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(color_dim, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 3
#model.add(Activation("sigmoid"))

# %%
# https://www.depends-on-the-definition.com/unet-keras-segmenting-images/

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(4, 4), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    
    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
'''def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model'''
# Out:
# "def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):\n    # contracting path\n    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    \n    # expansive path\n    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)\n    u6 = Dropout(dropout)(u6)\n    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)\n\n    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)\n    u7 = Dropout(dropout)(u7)\n    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)\n\n    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)\n    u8 = Dropout(dropout)(u8)\n    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)\n\n    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)\n    u9 = Dropout(dropout)(u9)\n    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)\n    model = Model(inputs=[input_img], outputs=[outputs])\n    return model"

# %%
input_img = Input((in_height, in_width, color_dim), name='img')
model = create_network(input_img, n_filters=8, dropout=0.05, batchnorm=True)

# %%
model.compile(loss='mean_squared_error', optimizer = RMSprop(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 256, 64)      1792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# activation_2 (Activation)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 256, 256, 32)      18464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# activation_3 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# activation_4 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 256, 256, 16)      4624
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256, 256, 16)      64
# _________________________________________________________________
# activation_5 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256, 256, 16)      64
# _________________________________________________________________
# activation_6 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 256, 256, 8)       1160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_7 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_8 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 256, 256, 3)       27
# =================================================================
# Total params: 125,187
# Trainable params: 124,707
# Non-trainable params: 480
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model_14.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
batch_size = 32
epochs = 50
trainHistory = model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_test, y_test),callbacks=callbacks)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 418s 52ms/step - loss: 0.0281 - acc: 0.5878 - val_loss: 0.0204 - val_acc: 0.6317
#
# Epoch 00001: val_loss improved from inf to 0.02044, saving model to model-tgs-salt.h5
# Epoch 2/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0110 - acc: 0.6095 - val_loss: 0.0212 - val_acc: 0.5643
#
# Epoch 00002: val_loss did not improve from 0.02044
# Epoch 3/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0099 - acc: 0.6357 - val_loss: 0.0112 - val_acc: 0.6383
#
# Epoch 00003: val_loss improved from 0.02044 to 0.01115, saving model to model-tgs-salt.h5
# Epoch 4/50
# 8000/8000 [==============================] - 410s 51ms/step - loss: 0.0094 - acc: 0.6623 - val_loss: 0.0199 - val_acc: 0.6427
#
# Epoch 00004: val_loss did not improve from 0.01115
# Epoch 5/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0092 - acc: 0.6725 - val_loss: 0.0097 - val_acc: 0.6511
#
# Epoch 00005: val_loss improved from 0.01115 to 0.00966, saving model to model-tgs-salt.h5
# Epoch 6/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0089 - acc: 0.6781 - val_loss: 0.0112 - val_acc: 0.6065
#
# Epoch 00006: val_loss did not improve from 0.00966
# Epoch 7/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0086 - acc: 0.6860 - val_loss: 0.0145 - val_acc: 0.6324
#
# Epoch 00007: val_loss did not improve from 0.00966
# Epoch 8/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0086 - acc: 0.6882 - val_loss: 0.0080 - val_acc: 0.7063
#
# Epoch 00008: val_loss improved from 0.00966 to 0.00797, saving model to model-tgs-salt.h5
# Epoch 9/50
# 8000/8000 [==============================] - 410s 51ms/step - loss: 0.0084 - acc: 0.6912 - val_loss: 0.0104 - val_acc: 0.7221
#
# Epoch 00009: val_loss did not improve from 0.00797
# Epoch 10/50
# 8000/8000 [==============================] - 410s 51ms/step - loss: 0.0083 - acc: 0.6953 - val_loss: 0.0099 - val_acc: 0.6802
#
# Epoch 00010: val_loss did not improve from 0.00797
# Epoch 11/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0083 - acc: 0.6935 - val_loss: 0.0074 - val_acc: 0.7194
#
# Epoch 00011: val_loss improved from 0.00797 to 0.00739, saving model to model-tgs-salt.h5
# Epoch 12/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0081 - acc: 0.6929 - val_loss: 0.0078 - val_acc: 0.7114
#
# Epoch 00012: val_loss did not improve from 0.00739
# Epoch 13/50
# 8000/8000 [==============================] - 410s 51ms/step - loss: 0.0080 - acc: 0.6988 - val_loss: 0.0072 - val_acc: 0.7277
#
# Epoch 00013: val_loss improved from 0.00739 to 0.00719, saving model to model-tgs-salt.h5
# Epoch 14/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0079 - acc: 0.7006 - val_loss: 0.0089 - val_acc: 0.6954
#
# Epoch 00014: val_loss did not improve from 0.00719
# Epoch 15/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0079 - acc: 0.7007 - val_loss: 0.0073 - val_acc: 0.7139
#
# Epoch 00015: val_loss did not improve from 0.00719
# Epoch 16/50
# 8000/8000 [==============================] - 411s 51ms/step - loss: 0.0078 - acc: 0.7005 - val_loss: 0.0087 - val_acc: 0.7192
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00016: val_loss did not improve from 0.00719
# Epoch 17/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0074 - acc: 0.7083 - val_loss: 0.0069 - val_acc: 0.7339
#
# Epoch 00017: val_loss improved from 0.00719 to 0.00690, saving model to model-tgs-salt.h5
# Epoch 18/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0073 - acc: 0.7095 - val_loss: 0.0069 - val_acc: 0.7336
#
# Epoch 00018: val_loss improved from 0.00690 to 0.00685, saving model to model-tgs-salt.h5
# Epoch 19/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0073 - acc: 0.7083 - val_loss: 0.0068 - val_acc: 0.7327
#
# Epoch 00019: val_loss improved from 0.00685 to 0.00681, saving model to model-tgs-salt.h5
# Epoch 20/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0073 - acc: 0.7088 - val_loss: 0.0068 - val_acc: 0.7314
#
# Epoch 00020: val_loss improved from 0.00681 to 0.00680, saving model to model-tgs-salt.h5
# Epoch 21/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0073 - acc: 0.7079 - val_loss: 0.0069 - val_acc: 0.7366
#
# Epoch 00021: val_loss did not improve from 0.00680
# Epoch 22/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7079 - val_loss: 0.0069 - val_acc: 0.7339
#
# Epoch 00022: val_loss did not improve from 0.00680
# Epoch 23/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7092 - val_loss: 0.0069 - val_acc: 0.7234
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00023: val_loss did not improve from 0.00680
# Epoch 24/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7085 - val_loss: 0.0068 - val_acc: 0.7358
#
# Epoch 00024: val_loss improved from 0.00680 to 0.00676, saving model to model-tgs-salt.h5
# Epoch 25/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7100 - val_loss: 0.0068 - val_acc: 0.7329
#
# Epoch 00025: val_loss improved from 0.00676 to 0.00676, saving model to model-tgs-salt.h5
# Epoch 26/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7079 - val_loss: 0.0068 - val_acc: 0.7343
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00026: val_loss did not improve from 0.00676
# Epoch 27/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7090 - val_loss: 0.0068 - val_acc: 0.7352
#
# Epoch 00027: val_loss improved from 0.00676 to 0.00676, saving model to model-tgs-salt.h5
# Epoch 28/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7081 - val_loss: 0.0068 - val_acc: 0.7329
#
# Epoch 00028: val_loss improved from 0.00676 to 0.00675, saving model to model-tgs-salt.h5
# Epoch 29/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7092 - val_loss: 0.0068 - val_acc: 0.7332
#
# Epoch 00029: val_loss did not improve from 0.00675
# Epoch 30/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7089 - val_loss: 0.0068 - val_acc: 0.7356
#
# Epoch 00030: val_loss did not improve from 0.00675
# Epoch 31/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7095 - val_loss: 0.0068 - val_acc: 0.7325
#
# Epoch 00031: val_loss did not improve from 0.00675
# Epoch 32/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7088 - val_loss: 0.0068 - val_acc: 0.7343
#
# Epoch 00032: val_loss improved from 0.00675 to 0.00675, saving model to model-tgs-salt.h5
# Epoch 33/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7086 - val_loss: 0.0068 - val_acc: 0.7336
#
# Epoch 00033: val_loss did not improve from 0.00675
# Epoch 34/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0072 - acc: 0.7095 - val_loss: 0.0067 - val_acc: 0.7348
#
# Epoch 00034: val_loss improved from 0.00675 to 0.00674, saving model to model-tgs-salt.h5
# Epoch 35/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7086 - val_loss: 0.0067 - val_acc: 0.7330
#
# Epoch 00035: val_loss improved from 0.00674 to 0.00674, saving model to model-tgs-salt.h5
# Epoch 36/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0072 - acc: 0.7089 - val_loss: 0.0067 - val_acc: 0.7328
#
# Epoch 00036: val_loss did not improve from 0.00674
# Epoch 37/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0071 - acc: 0.7092 - val_loss: 0.0067 - val_acc: 0.7328
#
# Epoch 00037: val_loss did not improve from 0.00674
# Epoch 38/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7090 - val_loss: 0.0067 - val_acc: 0.7355
#
# Epoch 00038: val_loss did not improve from 0.00674
# Epoch 39/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0072 - acc: 0.7084 - val_loss: 0.0067 - val_acc: 0.7357
#
# Epoch 00039: val_loss improved from 0.00674 to 0.00673, saving model to model-tgs-salt.h5
# Epoch 40/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0072 - acc: 0.7098 - val_loss: 0.0068 - val_acc: 0.7322
#
# Epoch 00040: val_loss did not improve from 0.00673
# Epoch 41/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0072 - acc: 0.7091 - val_loss: 0.0068 - val_acc: 0.7360
#
# Epoch 00041: val_loss did not improve from 0.00673
# Epoch 42/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0071 - acc: 0.7094 - val_loss: 0.0067 - val_acc: 0.7355
#
# Epoch 00042: val_loss did not improve from 0.00673
# Epoch 43/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0071 - acc: 0.7076 - val_loss: 0.0067 - val_acc: 0.7343
#
# Epoch 00043: val_loss did not improve from 0.00673
# Epoch 44/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0071 - acc: 0.7100 - val_loss: 0.0068 - val_acc: 0.7352
#
# Epoch 00044: val_loss did not improve from 0.00673
# Epoch 45/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0072 - acc: 0.7080 - val_loss: 0.0067 - val_acc: 0.7326
#
# Epoch 00045: val_loss did not improve from 0.00673
# Epoch 46/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0071 - acc: 0.7093 - val_loss: 0.0067 - val_acc: 0.7324
#
# Epoch 00046: val_loss did not improve from 0.00673
# Epoch 47/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0071 - acc: 0.7102 - val_loss: 0.0067 - val_acc: 0.7342
#
# Epoch 00047: val_loss improved from 0.00673 to 0.00673, saving model to model-tgs-salt.h5
# Epoch 48/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0071 - acc: 0.7102 - val_loss: 0.0067 - val_acc: 0.7343
#
# Epoch 00048: val_loss did not improve from 0.00673
# Epoch 49/50
# 8000/8000 [==============================] - 408s 51ms/step - loss: 0.0071 - acc: 0.7103 - val_loss: 0.0067 - val_acc: 0.7325
#
# Epoch 00049: val_loss did not improve from 0.00673
# Epoch 50/50
# 8000/8000 [==============================] - 409s 51ms/step - loss: 0.0071 - acc: 0.7101 - val_loss: 0.0067 - val_acc: 0.7352
#
# Epoch 00050: val_loss improved from 0.00673 to 0.00672, saving model to model-tgs-salt.h5

# %%
loss = trainHistory.history['loss']
val_loss = trainHistory.history['val_loss']
epochsRange = range(len(trainHistory.history['loss']))
plt.figure()
plt.plot(epochsRange, loss, label='Training loss',color='g')
plt.plot(epochsRange, val_loss, label='Validation loss',color='b')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
plt.plot(trainHistory.history['acc'])
plt.plot(trainHistory.history['val_acc'])
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
print(trainHistory.history.keys())
# Out:
# dict_keys(['lr', 'acc', 'loss', 'val_acc', 'val_loss'])

# %%
pred = model.predict(X_test)

# %%
#plt.figure(figsize=(256, 256))
print("Test Images")

for i in range(10):
    #plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(pred[i])
    #plt.title("(Label: " + str(label_dict[curr_lbl]) + ")")
    plt.show()
# Out:
# Test Images

# %%
plt.imshow(pred[0])
