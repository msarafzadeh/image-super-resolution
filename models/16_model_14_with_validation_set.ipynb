# %%
import os
import math
import random
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from skimage.io import imshow
#from sklearn.model_selection import train_test_split

#import tensorflow as tf

import keras

from keras.preprocessing.image import img_to_array, load_img
from keras.layers import Conv2D
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K

np.random.seed(1337)
# Out:
# Using TensorFlow backend.

# %%
#making sure GPU is in use 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9404251720061548817
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11285289370
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13147316254639362119
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Set some parameters
in_height = 64
in_width = 64
out_height = 256
out_width = 256
color_dim = 3
path_in = '/home/Matthew/image-super-resolution/data/imagenet/10k/res64noisy/'
path_out = '/home/Matthew/image-super-resolution/data/imagenet/10k/res256/'

# %%
#todo: add random shuffle . seed = 0

def load_images(path_in, path_out, test_size, valid_size):
    images = next(os.walk(path_in))[2] #oswalk is a generator 
    num_images = len(images)
  
    testSize  = int(test_size * num_images)
    validSize = int(valid_size * num_images)
    trainSize = int(math.ceil((1-(test_size+valid_size)) * num_images))
    
    X_train = np.zeros((trainSize,in_height,in_width,color_dim), dtype=np.float32)
    X_test = np.zeros((testSize,in_height,in_width,color_dim), dtype=np.float32)
    X_valid = np.zeros((validSize,in_height,in_width,color_dim), dtype=np.float32)

    y_train = np.zeros((trainSize,out_height,out_width,color_dim), dtype=np.float32)
    y_test  = np.zeros((testSize,out_height,out_width,color_dim), dtype=np.float32)
    y_valid  = np.zeros((validSize,out_height,out_width,color_dim), dtype=np.float32)
    
    trainIdx = 0
    testIdx = 0
    validIdx = 0
    for idx, image in enumerate(images):
        image_in_path = os.path.join(path_in,image)
        image_out_path = os.path.join(path_out,image)

        image_in_raw =  load_img(image_in_path, grayscale=False)
        image_out_raw = load_img(image_out_path, grayscale=False)

        #converts image to keras preprocessing image, then divide by 255 to un-invert the images
        image_in = (img_to_array(image_in_raw)).squeeze() / 255 
        image_out = (img_to_array(image_out_raw)).squeeze() / 255          
 
        try:
            if (idx % 1000 == 0):
                print("Stage " + str(idx))
        
            if (idx < testSize):
                #print("testIdx " + str(testIdx))
                X_test[testIdx] = image_in
                y_test[testIdx] = image_out
                testIdx+=1
                
            elif (idx < testSize + validSize):
                #print("validIdx " + str(validIdx))
                X_valid[validIdx] = image_in
                y_valid[validIdx] = image_out
                validIdx+=1
                
            else:
                #print("trainIdx " + str(trainIdx))
                X_train[trainIdx] = image_in
                y_train[trainIdx] = image_out
                trainIdx+=1
                
        except Exception as e: 
            print("\nERROR!!!!")
            print(image_in.shape)
            print(trainIdx)
            
            print(image_out.shape)
            print(testIdx)
            
            print("id "+str(idx))
            print(image_in_path)
            print(e)
           
            print("\n")
            
    return X_train,X_valid,X_test,y_train,y_valid,y_test

# %%
X_train,X_valid,X_test,y_train,y_valid,y_test = load_images(path_in, path_out, .2, .2)
# Out:
# Stage 0
# Stage 1000
# Stage 2000
# Stage 3000
# Stage 4000
# Stage 5000
# Stage 6000
# Stage 7000
# Stage 8000
# Stage 9000

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.core import Activation
from keras import backend as K
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from keras.optimizers import RMSprop

# %%
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers import  BatchNormalization, Activation, Dropout, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
#padding output size: see http://cs231n.github.io/convolutional-networks/
# output = (W−F+2P)/S+1   w- input size, f-kernel size, p-padding size

# %%
#model = Sequential()
#inputShape = (in_height, in_width, color_dim)
#model.add(UpSampling2D((4,4),input_shape=inputShape))
#model.add(Conv2D(32, (9, 9), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 32
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(16, (7, 7), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 16
#model.add(Activation("relu"))
#model.add(Conv2D(color_dim, (5, 5), padding='same', kernel_initializer="he_normal")) # 256 X 256 X 3
#model.add(Activation("sigmoid"))

# %%
# https://www.depends-on-the-definition.com/unet-keras-segmenting-images/

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(4, 4), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    
    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
'''def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model'''
# Out:
# "def create_network(input_img, n_filters=16, dropout=0.5, batchnorm=True):\n    # contracting path\n    #c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    \n    # expansive path\n    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same')(input_img)\n    u6 = Dropout(dropout)(u6)\n    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)\n\n    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)\n    u7 = Dropout(dropout)(u7)\n    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)\n\n    u8 = Conv2DTranspose(n_filters*2, (3, 3), padding='same') (c7)\n    u8 = Dropout(dropout)(u8)\n    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)\n\n    u9 = Conv2DTranspose(n_filters*1, (3, 3), padding='same') (c8)\n    u9 = Dropout(dropout)(u9)\n    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)\n    \n    outputs = Conv2D(color_dim, (1, 1), activation='sigmoid') (c9)\n    model = Model(inputs=[input_img], outputs=[outputs])\n    return model"

# %%
input_img = Input((in_height, in_width, color_dim), name='img')
model = create_network(input_img, n_filters=8, dropout=0.05, batchnorm=True)

# %%
model.compile(loss='mean_squared_error', optimizer = RMSprop(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 256, 64)      1792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# activation_2 (Activation)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 256, 256, 32)      18464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# activation_3 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# activation_4 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 256, 256, 16)      4624
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256, 256, 16)      64
# _________________________________________________________________
# activation_5 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256, 256, 16)      64
# _________________________________________________________________
# activation_6 (Activation)    (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 256, 256, 8)       1160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_7 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_8 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 256, 256, 3)       27
# =================================================================
# Total params: 125,187
# Trainable params: 124,707
# Non-trainable params: 480
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model_16.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
batch_size = 32
epochs = 50
trainHistory = model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_valid, y_valid),callbacks=callbacks)
# Out:
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/50
# 6000/6000 [==============================] - 330s 55ms/step - loss: 0.0328 - acc: 0.5765 - val_loss: 0.0246 - val_acc: 0.4799
#
# Epoch 00001: val_loss improved from inf to 0.02455, saving model to model_16.h5
# Epoch 2/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0123 - acc: 0.5946 - val_loss: 0.0204 - val_acc: 0.6077
#
# Epoch 00002: val_loss improved from 0.02455 to 0.02043, saving model to model_16.h5
# Epoch 3/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0105 - acc: 0.6153 - val_loss: 0.0278 - val_acc: 0.6395
#
# Epoch 00003: val_loss did not improve from 0.02043
# Epoch 4/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0099 - acc: 0.6366 - val_loss: 0.0104 - val_acc: 0.6618
#
# Epoch 00004: val_loss improved from 0.02043 to 0.01037, saving model to model_16.h5
# Epoch 5/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0096 - acc: 0.6421 - val_loss: 0.0094 - val_acc: 0.6741
#
# Epoch 00005: val_loss improved from 0.01037 to 0.00945, saving model to model_16.h5
# Epoch 6/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0094 - acc: 0.6505 - val_loss: 0.0208 - val_acc: 0.6234
#
# Epoch 00006: val_loss did not improve from 0.00945
# Epoch 7/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0091 - acc: 0.6547 - val_loss: 0.0136 - val_acc: 0.6188
#
# Epoch 00007: val_loss did not improve from 0.00945
# Epoch 8/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0089 - acc: 0.6607 - val_loss: 0.0126 - val_acc: 0.5854
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00008: val_loss did not improve from 0.00945
# Epoch 9/50
# 6000/6000 [==============================] - 322s 54ms/step - loss: 0.0083 - acc: 0.6705 - val_loss: 0.0078 - val_acc: 0.6800
#
# Epoch 00009: val_loss improved from 0.00945 to 0.00775, saving model to model_16.h5
# Epoch 10/50
# 6000/6000 [==============================] - 322s 54ms/step - loss: 0.0082 - acc: 0.6704 - val_loss: 0.0077 - val_acc: 0.6855
#
# Epoch 00010: val_loss improved from 0.00775 to 0.00768, saving model to model_16.h5
# Epoch 11/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0081 - acc: 0.6732 - val_loss: 0.0075 - val_acc: 0.6758
#
# Epoch 00012: val_loss improved from 0.00756 to 0.00754, saving model to model_16.h5
# Epoch 13/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0081 - acc: 0.6721 - val_loss: 0.0076 - val_acc: 0.6892
#
# Epoch 00013: val_loss did not improve from 0.00754
# Epoch 14/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0081 - acc: 0.6720 - val_loss: 0.0076 - val_acc: 0.6753
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00014: val_loss did not improve from 0.00754
# Epoch 15/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0081 - acc: 0.6718 - val_loss: 0.0074 - val_acc: 0.6867
#
# Epoch 00015: val_loss improved from 0.00754 to 0.00743, saving model to model_16.h5
# Epoch 16/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0080 - acc: 0.6727 - val_loss: 0.0074 - val_acc: 0.6856
#
# Epoch 00016: val_loss improved from 0.00743 to 0.00740, saving model to model_16.h5
# Epoch 17/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0080 - acc: 0.6739 - val_loss: 0.0074 - val_acc: 0.6858
#
# Epoch 00017: val_loss did not improve from 0.00740
# Epoch 18/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0080 - acc: 0.6736 - val_loss: 0.0074 - val_acc: 0.6849
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00018: val_loss improved from 0.00740 to 0.00736, saving model to model_16.h5
# Epoch 19/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0080 - acc: 0.6724 - val_loss: 0.0074 - val_acc: 0.6858
#
# Epoch 00019: val_loss did not improve from 0.00736
# Epoch 20/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0080 - acc: 0.6733 - val_loss: 0.0074 - val_acc: 0.6846
#
# Epoch 00020: val_loss did not improve from 0.00736
# Epoch 21/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0079 - acc: 0.6733 - val_loss: 0.0074 - val_acc: 0.6858
#
# Epoch 00021: val_loss did not improve from 0.00736
# Epoch 22/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6758 - val_loss: 0.0074 - val_acc: 0.6861
#
# Epoch 00022: val_loss did not improve from 0.00736
# Epoch 23/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6748 - val_loss: 0.0074 - val_acc: 0.6874
#
# Epoch 00023: val_loss improved from 0.00736 to 0.00735, saving model to model_16.h5
# Epoch 24/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0080 - acc: 0.6735 - val_loss: 0.0074 - val_acc: 0.6886
#
# Epoch 00024: val_loss did not improve from 0.00735
# Epoch 25/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6759 - val_loss: 0.0074 - val_acc: 0.6864
#
# Epoch 00025: val_loss did not improve from 0.00735
# Epoch 26/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6742 - val_loss: 0.0074 - val_acc: 0.6841
#
# Epoch 00026: val_loss did not improve from 0.00735
# Epoch 27/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6738 - val_loss: 0.0074 - val_acc: 0.6846
#
# Epoch 00027: val_loss did not improve from 0.00735
# Epoch 28/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6743 - val_loss: 0.0073 - val_acc: 0.6867
#
# Epoch 00028: val_loss improved from 0.00735 to 0.00734, saving model to model_16.h5
# Epoch 29/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6753 - val_loss: 0.0074 - val_acc: 0.6847
#
# Epoch 00029: val_loss did not improve from 0.00734
# Epoch 30/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6750 - val_loss: 0.0074 - val_acc: 0.6865
#
# Epoch 00030: val_loss did not improve from 0.00734
# Epoch 31/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6738 - val_loss: 0.0073 - val_acc: 0.6850
#
# Epoch 00031: val_loss improved from 0.00734 to 0.00734, saving model to model_16.h5
# Epoch 32/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0079 - acc: 0.6737 - val_loss: 0.0074 - val_acc: 0.6869
#
# Epoch 00032: val_loss did not improve from 0.00734
# Epoch 33/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6747 - val_loss: 0.0074 - val_acc: 0.6877
#
# Epoch 00033: val_loss did not improve from 0.00734
# Epoch 34/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6753 - val_loss: 0.0074 - val_acc: 0.6877
#
# Epoch 00034: val_loss did not improve from 0.00734
# Epoch 35/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6742 - val_loss: 0.0073 - val_acc: 0.6841
#
# Epoch 00035: val_loss improved from 0.00734 to 0.00733, saving model to model_16.h5
# Epoch 36/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6748 - val_loss: 0.0074 - val_acc: 0.6857
#
# Epoch 00036: val_loss did not improve from 0.00733
# Epoch 37/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6744 - val_loss: 0.0074 - val_acc: 0.6875
#
# Epoch 00037: val_loss did not improve from 0.00733
# Epoch 38/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6752 - val_loss: 0.0074 - val_acc: 0.6878
#
# Epoch 00038: val_loss did not improve from 0.00733
# Epoch 39/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6748 - val_loss: 0.0073 - val_acc: 0.6840
#
# Epoch 00039: val_loss did not improve from 0.00733
# Epoch 40/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6754 - val_loss: 0.0073 - val_acc: 0.6869
#
# Epoch 00040: val_loss did not improve from 0.00733
# Epoch 41/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0079 - acc: 0.6744 - val_loss: 0.0074 - val_acc: 0.6874
#
# Epoch 00041: val_loss did not improve from 0.00733
# Epoch 42/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0079 - acc: 0.6745 - val_loss: 0.0073 - val_acc: 0.6885
#
# Epoch 00042: val_loss improved from 0.00733 to 0.00732, saving model to model_16.h5
# Epoch 43/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0078 - acc: 0.6756 - val_loss: 0.0073 - val_acc: 0.6841
#
# Epoch 00043: val_loss did not improve from 0.00732
# Epoch 44/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0079 - acc: 0.6756 - val_loss: 0.0073 - val_acc: 0.6864
#
# Epoch 00044: val_loss did not improve from 0.00732
# Epoch 45/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0078 - acc: 0.6771 - val_loss: 0.0073 - val_acc: 0.6905
#
# Epoch 00045: val_loss did not improve from 0.00732
# Epoch 46/50
# 6000/6000 [==============================] - 321s 53ms/step - loss: 0.0078 - acc: 0.6768 - val_loss: 0.0074 - val_acc: 0.6842
#
# Epoch 00046: val_loss did not improve from 0.00732
# Epoch 47/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6759 - val_loss: 0.0073 - val_acc: 0.6863
#
# Epoch 00047: val_loss improved from 0.00732 to 0.00732, saving model to model_16.h5
# Epoch 48/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6725 - val_loss: 0.0073 - val_acc: 0.6863
#
# Epoch 00048: val_loss improved from 0.00732 to 0.00732, saving model to model_16.h5
# Epoch 49/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0079 - acc: 0.6753 - val_loss: 0.0073 - val_acc: 0.6867
#
# Epoch 00049: val_loss did not improve from 0.00732
# Epoch 50/50
# 6000/6000 [==============================] - 321s 54ms/step - loss: 0.0078 - acc: 0.6752 - val_loss: 0.0073 - val_acc: 0.6872
#
# Epoch 00050: val_loss did not improve from 0.00732

# %%
loss = trainHistory.history['loss']
val_loss = trainHistory.history['val_loss']
epochsRange = range(len(trainHistory.history['loss']))
plt.figure()
plt.plot(epochsRange, loss, label='Training loss',color='g')
plt.plot(epochsRange, val_loss, label='Validation loss',color='b')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
plt.plot(trainHistory.history['acc'])
plt.plot(trainHistory.history['val_acc'])
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
print(trainHistory.history.keys())
# Out:
# dict_keys(['val_acc', 'acc', 'val_loss', 'loss', 'lr'])

# %%
pred = model.predict(X_test)

# %%
#plt.figure(figsize=(256, 256))
print("Test Images")

for i in range(20):
    #plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(pred[i])
    #plt.title("(Label: " + str(label_dict[curr_lbl]) + ")")
    plt.show()
# Out:
# Test Images
